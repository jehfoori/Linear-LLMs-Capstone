# %% [markdown]
# # NIAH Remote Smoke Runner
#
# Use this notebook as a thin launcher. Keep experiment logic in the repo.

# %%
# In Colab, clone or upload the repo, then run:
# %cd /content/Capstone
# !pip install -e ".[mamba2]"
# !python -m niah.cli.generate_dataset --config configs/dataset_d20_paired.yaml --out datasets/d20_paired.jsonl
# !python -m niah.cli.evaluate --dataset datasets/d20_paired.jsonl --model-config configs/model_mamba2_official.yaml --out results/mamba2_official_d20_paired
# !python -m niah.cli.analyze_results --run-dir results/mamba2_official_d20_paired
# !zip -r mamba2_official_d20_paired.zip results/mamba2_official_d20_paired
